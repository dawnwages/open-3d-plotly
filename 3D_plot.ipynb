# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import seaborn as sns
import plotly.express as px
import cufflinks as cf
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
arr_1 = pd.read_csv('Whither_Cyber_Insurance_Fake_Data.csv')
df_1 = pd.DataFrame(arr_1)
df_1.head()
df_1.plot()
# Out:
# <AxesSubplot:>

# %%
fig = px.scatter_3d(df_1, x='Govt tail risk bearing', y='Govt standard setting & regulation', z='Govt threat management',
              color='Insurance type')
fig.show()
# Out:
# <div>                            <div id="524c3f8c-f5ac-4062-b630-3a730fd3e0da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("524c3f8c-f5ac-4062-b630-3a730fd3e0da")) {                    Plotly.newPlot(                        "524c3f8c-f5ac-4062-b630-3a730fd3e0da",                        [{"hovertemplate":"Insurance type=Kidnap & ransom<br>Govt tail risk bearing=%{x}<br>Govt standard setting & regulation=%{y}<br>Govt threat management=%{z}<extra></extra>","legendgroup":"Kidnap & ransom","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Kidnap & ransom","scene":"scene","showlegend":true,"type":"scatter3d","x":[0],"y":[2],"z":[4]},{"hovertemplate":"Insurance type=Art theft<br>Govt tail risk bearing=%{x}<br>Govt standard setting
# ...

# %%
df = pd.DataFrame(dict(
    r=[1, 5, 2, 2, 3],
    theta=['processing cost','mechanical properties','chemical stability',
           'thermal stability', 'device integration']))
fig = px.line_polar(df, r='r', theta='theta', line_close=True)
# fig.show()
df.head()
# Out:
#    r                  theta
# 0  1        processing cost
# 1  5  mechanical properties
# 2  2     chemical stability
# 3  2      thermal stability
# 4  3     device integration

# %%
# Bubble Chart: https://plotly.com/python/3d-bubble-charts/
df_1.head()
# Out:
#             Insurance type  Govt standard setting & regulation  \
# 0          Kidnap & ransom                                   2
# 1                Art theft                                   3
# 2          Arctic shipping                                   4
# 3  Environmental liability                                   8
# 4                Terrorism                                   2
#
#    Govt threat management  Govt tail risk bearing
# 0                       4                       0
# 1                       5                       6
# 2                       1                       1
# 3                       6                       4
# 4                       6                       8

# %%
fig = px.line_polar(df_1, r='Govt standard setting & regulation', theta='Insurance type', line_close=True)
fig.update_traces(fill='toself')
fig.show()
# Out:
# <div>                            <div id="0dc14889-0606-4565-b875-664334d7c194" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0dc14889-0606-4565-b875-664334d7c194")) {                    Plotly.newPlot(                        "0dc14889-0606-4565-b875-664334d7c194",                        [{"fill":"toself","hovertemplate":"Govt standard setting & regulation=%{r}<br>Insurance type=%{theta}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","r":[2,3,4,8,2,5,0,2],"showlegend":false,"subplot":"polar","theta":["Kidnap & ransom","Art theft","Arctic shipping","Environmental liability","Terrorism","D&O","Ransomware","Kidnap & ransom"],"type":"scatterpolar"}],                     
# ...

# %%
categories = df_1['Insurance type']
fig = go.Figure()
fig.add_trace(go.Scatterpolar(
    # WIP - Multiple Trace Radar Chart
    # https://plotly.com/python/radar-chart/
))
print(categories)
# Out:
# 0            Kidnap & ransom
# 1                  Art theft
# 2            Arctic shipping
# 3    Environmental liability
# 4                  Terrorism
# 5                        D&O
# 6                 Ransomware
# Name: Insurance type, dtype: object
